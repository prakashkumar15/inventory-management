# %%
data={
  101: {'expirydate': '6monthafter',
  'price': 10,
  'productname': 'Aero Caramel',
  'productof': 'Nestle',
  'quanity': 30},
 102: {'expirydate': '6monthafter',
  'price': 10,
  'productname': 'Aero Dark',
  'productof': 'Nestle',
  'quanity': 30},
 103: {'expirydate': '12monthafter',
  'price': 5,
  'productname': 'Aero Duet',
  'productof': 'Nestle',
  'quanity': 40},
 104: {'expirydate': '4monthafter',
  'price': 25,
  'productname': 'Aero Mint',
  'productof': 'Nestle',
  'quanity': 50},
 105: {'expirydate': '6monthafter',
  'price': 20,
  'productname': 'Aero Orange',
  'productof': 'Nestle',
  'quanity': 80},
 106: {'expirydate': '12monthafter',
  'price': 10,
  'productname': 'Almond Joy',
  'productof': 'Hershey',
  'quanity': 50},
 107: {'expirydate': '6monthafter',
  'price': 20,
  'productname': 'Almond Joy Milk Chocolate Passion Fruit',
  'productof': 'Hersheys',
  'quanity': 30},
 108: {'expirydate': '12 month after',
  'price': 5,
  'productname': ' Almond Joy Piña Colada',
  'productof': 'Hershey',
  'quanity': 50},
 109: {'expirydate': '12 month after',
  'price': 80,
  'productname': 'Almond Joy Toasted Coconut',
  'productof': 'Hershey',
  'quanity': 40},
 110: {'expirydate': '12 month after',
  'price': 10,
  'productname': 'Almond Joy White Chocolate Key Lime',
  'productof': 'Hershey',
  'quanity': 30},
 111: {'expirydate': '6 month after',
  'price': 5,
  'productname': 'Amul Chocolate',
  'productof': 'Anand Milk Union Limited',
  'quanity': 20},
 112: {'expirydate': '24 hours after',
  'price': 15,
  'productname': 'Aztec',
  'productof': 'Cadburry',
  'quanity': 50},
 113: {'expirydate': '2 month safter',
  'price': 20,
  'productname': 'Baby Ruth',
  'productof': 'Ferrara',
  'quanity': 50},
 114: {'expirydate': '12monthafter',
  'price': 1,
  'productname': 'Balisto',
  'productof': 'Masterwood',
  'quanity': 150},
 115: {'expirydate': '12monthafter',
  'price': 10,
  'productname': 'Cadbury Dairy Milk',
  'productof': 'Cadbury',
  'quanity': 50},
 116: {'expirydate': '6 month after',
  'price': 5,
  'productname': 'Cadbury Dairy Milk Biscuit',
  'productof': 'Cadbury',
  'quanity': 25},
 117: {'expirydate': '6 month after',
  'price': 80,
  'productname': 'Cadbury Dairy Milk Caramel',
  'productof': 'Cadburry',
  'quanity': 20},
 118: {'expirydate': '8 month after',
  'price': 45,
  'productname': 'Cadbury Dairy Milk Coconut Cashew',
  'productof': 'Cadburry',
  'quanity': 30},
 119: {'expirydate': '6 month after',
  'price': 150,
  'productname': 'Five Star Caramel',
  'productof': 'Lake Champlain ',
  'quanity': 5},
 120: {'expirydate': '5monthafter',
  'price': 15,
  'productname': 'Kit Kat',
  'productof': 'Nestley',
  'quanity': 20},
 121: {'expirydate': '9 month after',
  'price': 10,
  'productname': 'Milky Bar',
  'productof': 'Nestley',
  'quanity': 20},
 122: {'expirydate': '12 month after',
  'price': 60,
  'productname': 'Sky Bar',
  'productof': 'Necco',
  'quanity': 25},
 123: {'expirydate': '8 month after',
  'price': 45,
  'productname': 'sting',
  'productof': 'sting energy',
  'quanity': 15},
 124: {'expirydate': '12 month after',
  'price': 10,
  'productname': 'soda',
  'productof': 'cocacola',
  'quanity': 50},
 125: {'expirydate': '12 month after',
  'price': 40,
  'productname': 'Snickers',
  'productof': 'Mars',
  'quanity': 50},
 126: {'expirydate': '12 month after',
  'price': 40,
  'productname': 'Spira',
  'productof': 'Cadbury',
  'quanity': 20},
 127: {'expirydate': '12 month after',
  'price': 30,
  'productname': 'Munch',
  'productof': 'Nestley',
  'quanity': 10},
 128: {'expirydate': '12 month after',
  'price': 45,
  'productname': 'Bruce',
  'productof': 'Nestley',
  'quanity': 20},
 129: {'expirydate': '12 month after',
  'price': 40,
  'productname': 'Thumbsup',
  'productof': 'cocacola',
  'quanity': 30},
 130: {'expirydate': '6 month after',
  'price': 35,
  'productname': 'Snickers Crisp',
  'productof': 'Mars',
  'quanity': 20}
}

import json
json.dumps(data)
dict.keys(data)
lst = []
for i in dict.keys(data):
        lst.append(i)

import time
productID= int(input("Enter the product id that you want add into cart :: "))
Quantity= input("Enter the quantity ::")

for i in range(30):
    if(lst[i] == int(productID)):
        print("*********** Welcome Sir..*********\n")
        print("Added Product ::"+data[productID]["productname"]+"_ in the list \n")
        amount=data[productID]["price"] * int(Quantity)
        print("************PayOut Bill************")
        print("Amount :: ",amount)
        print("Brand :: "+ data[productID]["productof"])
        print("Expiry Data ::"+data[productID]["expirydate"])
        print("Time :: ")
        top=time.ctime()
        print(top)
        print("Thanks You,Sir!!")
        k=data[productID]["quanity"]
        k=int(k)-int(Quantity)
        data[productID]["quanity"]=k
        print(k)
        break
    else:
        continue

fp=open("sales.jason", "w")
fp.write(str(data))
fp.close()
